# %%
import pandas as pd

# dataset from data.world (NBA Finals and MVPs)
# dataset url https://data.world/datatouille/nba-finals-and-mvps

df = pd.read_csv('./datatouille-nba-finals-and-mvps/data/data.csv')

# %%
# check it is loaded
df.head()
# Out:
#    year    western_champion    eastern_champion result        nba_champion  \
# 0  1950  Minneapolis Lakers  Syracuse Nationals    4–2  Minneapolis Lakers
# 1  1951    Rochester Royals     New York Knicks    4–3    Rochester Royals
# 2  1952  Minneapolis Lakers     New York Knicks    4–3  Minneapolis Lakers
# 3  1953  Minneapolis Lakers     New York Knicks    4–1  Minneapolis Lakers
# 4  1954  Minneapolis Lakers  Syracuse Nationals    4–3  Minneapolis Lakers
#
#     nba_vice_champion  final_sweep mvp_name  mvp_height_m  mvp_height_ft  \
# 0  Syracuse Nationals        False      NaN           NaN            NaN
# 1     New York Knicks        False      NaN           NaN            NaN
# 2     New York Knicks        False      NaN           NaN            NaN
# 3     New York Knicks        False      NaN           NaN            NaN
# 4  Syracuse Nationals        False      NaN           NaN            NaN
#
#   mvp_position mvp_team mvp_nationality mvp_status
# 0          NaN      NaN             NaN        NaN
# 1          NaN      NaN             NaN        NaN
# 2          NaN      NaN             NaN        NaN
# 3          NaN      NaN             NaN        NaN
# 4          NaN      NaN             NaN        NaN

# %% [markdown]
# ## No 1. 如果我是湖人迷那湖人隊在1980到2010拿了幾次總冠軍？

# %%
mask = df['year'].between(1980,2010)
df[mask][]
# Out:
#     year        western_champion     eastern_champion result  \
# 30  1980      Los Angeles Lakers   Philadelphia 76ers    4–2
# 31  1981         Houston Rockets       Boston Celtics    2–4
# 32  1982      Los Angeles Lakers   Philadelphia 76ers    4–2
# 33  1983      Los Angeles Lakers   Philadelphia 76ers    0–4
# 34  1984      Los Angeles Lakers       Boston Celtics    3–4
# 35  1985      Los Angeles Lakers       Boston Celtics    4–2
# 36  1986         Houston Rockets       Boston Celtics    2–4
# 37  1987      Los Angeles Lakers       Boston Celtics    4–2
# 38  1988      Los Angeles Lakers      Detroit Pistons    4–3
# 39  1989      Los Angeles Lakers      Detroit Pistons    0–4
# 40  1990  Portland Trail Blazers      Detroit Pistons    1–4
# 41  1991      Los Angeles Lakers        Chicago Bulls    1–4
# 42  1992  Portland Trail Blazers        Chicago Bulls    2–4
# 43  1993            Phoenix Suns        Chicago Bulls    2–4
# 44  1994         Houston Rockets      New York Knicks    4–3
# 45  1995         Houston Rockets        Orlando Magic    4–0
# 46  1996     Seattle SuperSonics        Chicago Bulls    2–4
# 47  1997               Utah Jazz        Chicago Bulls    2–4
# 48  1998               Utah Jazz        Chicago Bulls    2–4
# 49  1999       San Antonio Spurs      New York Knicks    4–1
# 50  2000      Los Angeles Lakers       Indiana Pacers    4–2
# 51  2001      Los Angeles Lakers   Philadelphia 76ers    4–1
# 52  2002      Los Angeles Lakers      New Jersey Nets    4–0
# 53  2003       San Antonio Spurs      New Jersey Nets    4–2
# 54  2004      Los Angeles Lakers      Detroit Pistons    1–4
# 55  2005       San Antonio Spurs      Detroit Pistons    4–3
# 56  2006        Dallas Mavericks           Miami Heat    2–4
# 57  2007       San Antonio Spurs  Cleveland Cavaliers    4–0
# 58  2008      Los Angeles Lakers       Boston Celtics    2–4
# 59  2009      Los Angeles Lakers        Orlando Magic    4–1
# 60  2010      Los Angeles Lakers       Boston Celtics    4–3
#
#           nba_champion       nba_vice_champion  final_sweep     mvp_name  \
# 30  Los Angeles Lakers      Philadelphia 76ers        False   K. AJabbar
# 31      Boston Celtics         Houston Rockets        False    J. Erving
# 32  Los Angeles Lakers      Philadelphia 76ers        False    M. Malone
# 33  Philadelphia 76ers      Los Angeles Lakers         True    M. Malone
# 34      Boston Celtics      Los Angeles Lakers        False      L. Bird
# 35  Los Angeles Lakers          Boston Celtics        False      L. Bird
# 36      Boston Celtics         Houston Rockets        False      L. Bird
# 37  Los Angeles Lakers          Boston Celtics        False   M. Johnson
# 38  Los Angeles Lakers         Detroit Pistons        False    M. Jordan
# 39     Detroit Pistons      Los Angeles Lakers         True   M. Johnson
# 40     Detroit Pistons  Portland Trail Blazers        False   M. Johnson
# 41       Chicago Bulls      Los Angeles Lakers        False    M. Jordan
# 42       Chicago Bulls  Portland Trail Blazers        False    M. Jordan
# 43       Chicago Bulls            Phoenix Suns        False   C. Barkley
# 44     Houston Rockets         New York Knicks        False  H. Olajuwon
# 45     Houston Rockets           Orlando Magic         True  D. Robinson
# 46       Chicago Bulls     Seattle SuperSonics        False    M. Jordan
# 47       Chicago Bulls               Utah Jazz        False    K. Malone
# 48       Chicago Bulls               Utah Jazz        False    M. Jordan
# 49   San Antonio Spurs         New York Knicks        False    K. Malone
# 50  Los Angeles Lakers          Indiana Pacers        False    S. O'Neal
# 51  Los Angeles Lakers      Philadelphia 76ers        False   A. Iverson
# 52  Los Angeles Lakers         New Jersey Nets         True    T. Duncan
# 53   San Antonio Spurs         New Jersey Nets        False    T. Duncan
# 54     Detroit Pistons      Los Angeles Lakers        False   K. Garnett
# 55   San Antonio Spurs         Detroit Pistons        False      S. Nash
# 56          Miami Heat        Dallas Mavericks        False      S. Nash
# 57   San Antonio Spurs     Cleveland Cavaliers         True  D. Nowitzki
# 58      Boston Celtics      Los Angeles Lakers        False    K. Bryant
# 59  Los Angeles Lakers           Orlando Magic        False     L. James
# 60  Los Angeles Lakers          Boston Celtics        False     L. James
#
#     mvp_height_m  mvp_height_ft mvp_position                mvp_team  \
# 30          2.18       7.152231       Center      Los Angeles Lakers
# 31          2.01       6.594488      Forward      Philadelphia 76ers
# 32          2.08       6.824147       Center         Houston Rockets
# 33          2.08       6.824147       Center      Philadelphia 76ers
# 34          2.06       6.758530      Forward          Boston Celtics
# 35          2.06       6.758530      Forward          Boston Celtics
# 36          2.06       6.758530      Forward          Boston Celtics
# 37          2.06       6.758530        Guard      Los Angeles Lakers
# 38          1.98       6.496063        Guard           Chicago Bulls
# 39          2.06       6.758530        Guard      Los Angeles Lakers
# 40          2.06       6.758530        Guard      Los Angeles Lakers
# 41          1.98       6.496063        Guard           Chicago Bulls
# 42          1.98       6.496063        Guard           Chicago Bulls
# 43          1.98       6.496063      Forward            Phoenix Suns
# 44          2.13       6.988189       Center         Houston Rockets
# 45          2.16       7.086614       Center       San Antonio Spurs
# 46          1.98       6.496063        Guard           Chicago Bulls
# 47          2.06       6.758530      Forward               Utah Jazz
# 48          1.98       6.496063        Guard           Chicago Bulls
# 49          2.06       6.758530      Forward               Utah Jazz
# 50          2.16       7.086614       Center      Los Angeles Lakers
# 51          1.83       6.003937        Guard      Philadelphia 76ers
# 52          2.11       6.922572      Forward       San Antonio Spurs
# 53          2.11       6.922572      Forward       San Antonio Spurs
# 54          2.11       6.922572      Forward  Minnesota Timberwolves
# 55          1.91       6.266404        Guard            Phoenix Suns
# 56          1.91       6.266404        Guard            Phoenix Suns
# 57          2.13       6.988189      Forward        Dallas Mavericks
# 58          1.98       6.496063        Guard      Los Angeles Lakers
# 59          2.03       6.660105      Forward     Cleveland Cavaliers
# 60          2.03       6.660105      Forward     Cleveland Cavaliers
#
#    mvp_nationality         mvp_status
# 30              US           Champion
# 31              US  Not reached Final
# 32              US  Not reached Final
# 33              US           Champion
# 34              US           Champion
# 35              US      Vice-Champion
# 36              US           Champion
# 37              US           Champion
# 38              US  Not reached Final
# 39              US      Vice-Champion
# 40              US  Not reached Final
# 41              US           Champion
# 42              US           Champion
# 43              US      Vice-Champion
# 44         Nigeria           Champion
# 45              US  Not reached Final
# 46              US           Champion
# 47              US      Vice-Champion
# 48              US           Champion
# 49              US  Not reached Final
# 50              US           Champion
# 51              US      Vice-Champion
# 52              US  Not reached Final
# 53              US           Champion
# 54              US  Not reached Final
# 55          Canada  Not reached Final
# 56          Canada  Not reached Final
# 57         Germany  Not reached Final
# 58              US      Vice-Champion
# 59              US  Not reached Final
# 60              US  Not reached Final

# %% [markdown]
# ## No 2. 這些年又有幾次是西區冠軍但是沒拿到總冠軍？

# %% [markdown]
# ## No 3. 這些年又有哪些人是湖人隊成員拿到例行賽ＭＶＰ？

# %% [markdown]
# ## No 4. 1980年到2000年例行賽MVP所屬位置的比例是多少？

# %% [markdown]
# ## No 5. 2000年到2018年例行賽MVP所屬位置的比例又是多少？

# %% [markdown]
# ## No 6. 1960年到2000年例行賽MVP平均身高？

# %% [markdown]
# ## No 7. 2000年到2018年例行賽MVP平均身高？

# %% [markdown]
# ## No 8.例行賽MVP選手主要都是哪個國家的人？

# %% [markdown]
# ## No 9. S.Curry在哪些年份拿到MVP?

# %% [markdown]
# ## No 10. 1980至今的東西區奪冠比例是？
